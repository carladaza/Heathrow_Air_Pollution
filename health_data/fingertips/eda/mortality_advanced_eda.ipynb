# %% [markdown]
# # DS4A Team 27: Single Variable Exploratory Data Analysis on Mortality Data

# %% [markdown]
# CONCLUSIONS:
#
# Mortality rates by sex:
# - We only have data by sex for one indicator: the mortality rate for people under 75 by respiratory disease. The rate of death for males is much higher than females. All other indicators only have data aggregated for persons, so we will continue analysis on persons data.
#
#
# Mortality rates over time:
# - Mortality rates from asthma and COPD as a contributory cause are rising over time
# - Mortality rates from pneumonia, coronary heart disease, and respiratory disease and falling over time
#
# Comparing inner and outer radius CCGs:
# - Mortality rates for all five indicators are higher in CCGs closer to the airport. The distinction is highest for pneumonia, coronary heart disease, and asthma.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ### 1. Load in the data

# %%
df_full = pd.read_csv('./cleaned_data_output/mortality_data_clean/cleaned_mortality_data.csv')
df_full.head(3)
# Out:
#    Unnamed: 0  Indicator ID  \
# 0           0          1204
# 1           1          1204
# 2           2          1204
#
#                                       Indicator Name  Area Code  \
# 0  Mortality rate from chronic obstructive pulmon...  E38000048
# 1  Mortality rate from chronic obstructive pulmon...  E38000082
# 2  Mortality rate from chronic obstructive pulmon...  E38000084
#
#             Area Name          Area Type      Sex       Age Time period  \
# 0      NHS Ealing CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
# 1  NHS Hillingdon CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
# 2    NHS Hounslow CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
#
#    Value  Lower CI 95.0 limit  Upper CI 95.0 limit  Lower CI 99.8 limit  \
# 0  42.30                36.95                48.20                34.11
# 1  47.58                41.92                53.78                38.90
# 2  54.46                47.24                62.46                43.42
#
#    Upper CI 99.8 limit  Count  Denominator Value note  \
# 0                51.76  228.0     958022.0        NaN
# 1                57.52  258.0     772419.0        NaN
# 2                67.29  210.0     699487.0        NaN
#
#   Compared to England value or percentiles  Time period Sortable Radius
# 0                                   Better                  2006  Inner
# 1                                  Similar                  2006  Inner
# 2                                  Similar                  2006  Inner

# %% [markdown]
# ### 2. Rename indicators and filter

# %%
# Make new (short) Indicator name column (for facetgrid viewing)
def new_name(old_name):
    name_dict = {
        'Mortality rate from chronic obstructive pulmonary disease': 'COPD', 
        'Under 75 mortality rate from respiratory disease': 'Under 75 Resp Disease',
        'Under 75 mortality rate from respiratory disease considered preventable (2016 definition)': '<75 RD Preventable 16',
        'Mortality rate from pneumonia (underlying cause)' : 'Pneumonia (underlying cause)',
        'Mortality rate from pneumonia (all mentions)': 'Pneumonia (all mentions)',
        'Mortality rate from COPD as a contributory cause' : 'COPD (contributory cause)',
        'Mortality rate from asthma' : 'Asthma', 
        'Under 75 mortality rate from respiratory disease considered preventable (2019 definition)': '<75 RD Preventable 19',
        'Coronary heart disease mortality rates, under 75 years' : '<75 Coronary Heart Disease',
        'Stroke mortality rates, under 75 years (age standardised)' : 'Under 75 Stroke',
        'Stroke mortality rates, over 75 years (age standardised)' : 'Over 75 Stroke'
    }
    
    return name_dict.get(old_name)
    
df_full["Indicator"] = df_full["Indicator Name"].apply(new_name)
df_full["Year"] = df_full["Time period Sortable"]
df_full.head(3)
# Out:
#    Unnamed: 0  Indicator ID  \
# 0           0          1204
# 1           1          1204
# 2           2          1204
#
#                                       Indicator Name  Area Code  \
# 0  Mortality rate from chronic obstructive pulmon...  E38000048
# 1  Mortality rate from chronic obstructive pulmon...  E38000082
# 2  Mortality rate from chronic obstructive pulmon...  E38000084
#
#             Area Name          Area Type      Sex       Age Time period  \
# 0      NHS Ealing CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
# 1  NHS Hillingdon CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
# 2    NHS Hounslow CCG  CCGs (since 4/20)  Persons  All ages   2006 - 08
#
#    Value  ...  Lower CI 99.8 limit  Upper CI 99.8 limit  Count  Denominator  \
# 0  42.30  ...                34.11                51.76  228.0     958022.0
# 1  47.58  ...                38.90                57.52  258.0     772419.0
# 2  54.46  ...                43.42                67.29  210.0     699487.0
#
#    Value note  Compared to England value or percentiles Time period Sortable  \
# 0         NaN                                    Better                 2006
# 1         NaN                                   Similar                 2006
# 2         NaN                                   Similar                 2006
#
#   Radius  Indicator  Year
# 0  Inner       COPD  2006
# 1  Inner       COPD  2006
# 2  Inner       COPD  2006
#
# [3 rows x 22 columns]

# %%
# List of indicators of interest (found in preliminary EDA)
indicators = ['Mortality rate from asthma',
    'Under 75 mortality rate from respiratory disease',
    'Coronary heart disease mortality rates, under 75 years',
    'Mortality rate from COPD as a contributory cause',
    'Mortality rate from pneumonia (all mentions)',]

full_indicators = list(df_full["Indicator Name"].unique())

# %% [markdown]
# ### 3. Analysis by sex

# %%
# Let's get a quick look at any differences or missing data by sex:
for i in indicators: 
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.boxplot(x="Year", y="Value", data=df_full[df_full["Indicator Name"] == i], ax=ax, hue='Sex')
    plt.xticks(rotation=90)
    title = "Boxplot timeseries for " + str(i)
    plt.title(title)

# %% [markdown]
# Conclusions:
# - We only have data by sex for one indicator: the mortality rate for people under 75 by respiratory disease. Clearly, the rate of death for males is higher than females. All other indicators only have data aggregated for persons.
#
# Let's continue our EDA on a subset of the data: persons.

# %% [markdown]
# ### 4. Data distribution

# %%
# continuing eda on a subset of data: persons 
df = df_full[df_full.Sex == 'Persons']

# %%
# Create series of histograms for each indicator 
plt.figure(figsize=(12,10))
for i, ind in enumerate(indicators): 
    temp_df = df[df["Indicator Name"] == ind]
    plt.subplot(3,2,i+1) 
    plt.hist(temp_df["Value"],25) 
    title = "Histogram for " + ind
    plt.title(title)

# %% [markdown]
# ### 5. Data distribution and trends over time

# %%
# Create boxplot timeseries for each indicator 
for i in indicators: 
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.boxplot(x="Year", y="Value", data=df[df["Indicator Name"] == i], ax=ax)
    plt.xticks(rotation=90)
    title = "Boxplot timeseries for " + str(i)
    plt.title(title)

# %%
# Create line plot for each indicator 
for i in indicators: 
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.lineplot(x="Year", y="Value", data=df[df["Indicator Name"] == i], ax=ax)
    plt.xticks(rotation=90)
    title = "Boxplot timeseries for " + str(i)
    plt.title(title)

# %% [markdown]
# Conclusions:
# - Mortality rates from asthma and COPD as a contributory cause are rising over time
# - Mortality rates from pneumonia, coronary heart disease, and respiratory disease and falling over time

# %% [markdown]
# ### 6. Compare inner and outer radius CCGs

# %%
# Now split it by inner and outer CCGs 
for i in indicators: 
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.boxplot(x="Year", y="Value", data=df[df["Indicator Name"] == i], ax=ax, hue='Radius')
    plt.xticks(rotation=90)
    title = "Boxplot timeseries for " + str(i)
    plt.title(title)

# %%
# Create series of line graphs comparing Inner and Outer radius 
for i in indicators: 
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.lineplot(x="Year", y="Value", data=df[df["Indicator Name"] == i], ax=ax, hue='Radius')
    plt.xticks(rotation=90)
    title = str(i) + ": comparing inner and outer radius of CCGs from Heathrow"
    plt.title(title)

# %% [markdown]
# Conclusions:
# - Mortality rates for all five indicators are higher in CCGs closer to the airport. The distinction is highest for pneumonia, coronary heart disease, and asthma.

# %% [markdown]
# ### 7. Subset data and export for multivariate EDA

# %%
df_5_indicators = df[df["Indicator Name"].isin(indicators)]
df_5_indicators["Indicator Name"].unique()
# Out:
# array(['Under 75 mortality rate from respiratory disease',
#        'Mortality rate from pneumonia (all mentions)',
#        'Mortality rate from COPD as a contributory cause',
#        'Coronary heart disease mortality rates, under 75 years',
#        'Mortality rate from asthma'], dtype=object)

# %%
# Export to csv 
directory = './cleaned_data_output/mortality_data_select'
if not os.path.exists(directory):
    os.makedirs(directory)

df_5_indicators.to_csv(directory + '/cleaned_mortality_data_select.csv')
