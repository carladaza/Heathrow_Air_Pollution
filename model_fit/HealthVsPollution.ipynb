# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
poll = pd.read_csv('../data_final/pollution_wide.csv').drop('Unnamed: 0', axis =1)

# %%
poll
# Out:
#                        Location  Date  Carbon monoxide  Nitric Oxide  \
# 0         Hounslow 2 - Cranford  2004              NaN     19.366907
# 1         Hounslow 2 - Cranford  2005              NaN     19.282252
# 2         Hounslow 2 - Cranford  2006              NaN     16.322724
# 3         Hounslow 2 - Cranford  2007              NaN     22.751626
# 4         Hounslow 2 - Cranford  2008              NaN     19.463412
# ..                          ...   ...              ...           ...
# 632              Oxford High St  2020              NaN           NaN
# 633  Oxford St Ebbes (Cal Club)  2020              NaN           NaN
# 634      Reading Caversham Road  2020              NaN           NaN
# 635         Reading Oxford Road  2020              NaN           NaN
# 636           Watford Town Hall  2020              NaN           NaN
#
#      Nitrogen dioxide  Oxides of Nitrogen      Ozone  PM10 Particulate matter  \
# 0           35.637110           65.183649  31.628426                22.091612
# 1           37.730687           66.993132  34.426010                22.159977
# 2           37.439653           62.493307  41.626836                22.695308
# 3           34.516199           69.260681  31.764437                21.877800
# 4           36.025263           65.728967  36.527434                19.221030
# ..                ...                 ...        ...                      ...
# 632         28.006868                 NaN        NaN                      NaN
# 633               NaN                 NaN  46.380779                      NaN
# 634         24.945059                 NaN        NaN                      NaN
# 635         19.730862                 NaN        NaN                      NaN
# 636         20.813022                 NaN        NaN                      NaN
#
#      PM10 particulate matter (Hourly measured)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 632                                  15.914070
# 633                                        NaN
# 634                                  20.666082
# 635                                  18.177858
# 636                                  13.758945
#
#      PM2.5 particulate matter (Hourly measured)  Sulphur dioxide       CCG  \
# 0                                           NaN         3.611565  Hounslow
# 1                                           NaN         3.959997  Hounslow
# 2                                           NaN         3.018580  Hounslow
# 3                                           NaN         2.886371  Hounslow
# 4                                           NaN         3.046298  Hounslow
# ..                                          ...              ...       ...
# 632                                         NaN              NaN    Oxford
# 633                                         NaN              NaN    Oxford
# 634                                         NaN              NaN   Reading
# 635                                         NaN              NaN   Reading
# 636                                    7.877282              NaN   Watford
#
#     Radius                            lat/long  distance_from_LHR
# 0    Inner            [51.4686132, -0.3613471]           6.440137
# 1    Inner            [51.4686132, -0.3613471]           6.440137
# 2    Inner            [51.4686132, -0.3613471]           6.440137
# 3    Inner            [51.4686132, -0.3613471]           6.440137
# 4    Inner            [51.4686132, -0.3613471]           6.440137
# ..     ...                                 ...                ...
# 632  Outer            [51.7520131, -1.2578499]          63.733402
# 633  Outer              [51.744856, -1.260338]          63.500050
# 634  Outer            [51.4591971, -0.9723236]          35.906170
# 635  Outer  [51.75397495, -1.2549151872177409]          63.663925
# 636  Outer            [51.6589841, -0.4032651]          21.305890
#
# [637 rows x 15 columns]

# %%
poll1 = poll[~poll.Location.str.contains("Heathrow")]

# %%
all_polls = list(poll1.drop(['Location', 'Date', 'CCG', 'Radius', 'lat/long', 'distance_from_LHR'], axis = 1).columns)


for p in all_polls:
    plt.figure(figsize=(10, 6))
    sns.lineplot(y= p,
                 x='Date',
                 hue = 'Radius',
                 data=poll1).set_title(p)
    plt.xticks(rotation=90)
    plt.show()
