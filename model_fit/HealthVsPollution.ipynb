# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
poll = pd.read_csv('../data_final/pollution_wide.csv')

# %%
poll
# Out:
#      Unnamed: 0                    Location  Date  Carbon monoxide  \
# 0             0       Hounslow 2 - Cranford  2004              NaN
# 1             1       Hounslow 2 - Cranford  2005              NaN
# 2             2       Hounslow 2 - Cranford  2006              NaN
# 3             3       Hounslow 2 - Cranford  2007              NaN
# 4             4       Hounslow 2 - Cranford  2008              NaN
# ..          ...                         ...   ...              ...
# 632         632              Oxford High St  2020              NaN
# 633         633  Oxford St Ebbes (Cal Club)  2020              NaN
# 634         634      Reading Caversham Road  2020              NaN
# 635         635         Reading Oxford Road  2020              NaN
# 636         636           Watford Town Hall  2020              NaN
#
#      Nitric Oxide  Nitrogen dioxide  Oxides of Nitrogen      Ozone  \
# 0       19.366907         35.637110           65.183649  31.628426
# 1       19.282252         37.730687           66.993132  34.426010
# 2       16.322724         37.439653           62.493307  41.626836
# 3       22.751626         34.516199           69.260681  31.764437
# 4       19.463412         36.025263           65.728967  36.527434
# ..            ...               ...                 ...        ...
# 632           NaN         28.006868                 NaN        NaN
# 633           NaN               NaN                 NaN  46.380779
# 634           NaN         24.945059                 NaN        NaN
# 635           NaN         19.730862                 NaN        NaN
# 636           NaN         20.813022                 NaN        NaN
#
#      PM10 Particulate matter  PM10 particulate matter (Hourly measured)  \
# 0                  22.091612                                        NaN
# 1                  22.159977                                        NaN
# 2                  22.695308                                        NaN
# 3                  21.877800                                        NaN
# 4                  19.221030                                        NaN
# ..                       ...                                        ...
# 632                      NaN                                  15.914070
# 633                      NaN                                        NaN
# 634                      NaN                                  20.666082
# 635                      NaN                                  18.177858
# 636                      NaN                                  13.758945
#
#      PM2.5 particulate matter (Hourly measured)  Sulphur dioxide       CCG  \
# 0                                           NaN         3.611565  Hounslow
# 1                                           NaN         3.959997  Hounslow
# 2                                           NaN         3.018580  Hounslow
# 3                                           NaN         2.886371  Hounslow
# 4                                           NaN         3.046298  Hounslow
# ..                                          ...              ...       ...
# 632                                         NaN              NaN    Oxford
# 633                                         NaN              NaN    Oxford
# 634                                         NaN              NaN   Reading
# 635                                         NaN              NaN   Reading
# 636                                    7.877282              NaN   Watford
#
#     Radius                            lat/long  distance_from_LHR
# 0    Inner            [51.4686132, -0.3613471]           6.440137
# 1    Inner            [51.4686132, -0.3613471]           6.440137
# 2    Inner            [51.4686132, -0.3613471]           6.440137
# 3    Inner            [51.4686132, -0.3613471]           6.440137
# 4    Inner            [51.4686132, -0.3613471]           6.440137
# ..     ...                                 ...                ...
# 632  Outer            [51.7520131, -1.2578499]          63.733402
# 633  Outer              [51.744856, -1.260338]          63.500050
# 634  Outer            [51.4591971, -0.9723236]          35.906170
# 635  Outer  [51.75397495, -1.2549151872177409]          63.663925
# 636  Outer            [51.6589841, -0.4032651]          21.305890
#
# [637 rows x 16 columns]

# %%
poll1 = poll[~poll.Location.str.contains("Heathrow")]

# %%
all_polls = list(poll1.drop(['Location', 'Date', 'CCG', 'Radius', 'lat/long', 'distance_from_LHR'], axis = 1).columns)


for p in all_polls:
    plt.figure(figsize=(10, 6))
    sns.lineplot(y= p,
                 x='Date',
                 hue = 'Radius',
                 data=poll1).set_title(p)
    plt.xticks(rotation=90)
    plt.show()
