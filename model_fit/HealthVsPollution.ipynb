# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
poll = pd.read_csv('../data_final/pollution_wide.csv').drop('Unnamed: 0', axis =1)

# %%
poll
# Out:
#                        Location  Date  Carbon monoxide  Nitric Oxide  \
# 0         Hounslow 2 - Cranford  2004              NaN     19.366907
# 1         Hounslow 2 - Cranford  2005              NaN     19.282252
# 2         Hounslow 2 - Cranford  2006              NaN     16.322724
# 3         Hounslow 2 - Cranford  2007              NaN     22.751626
# 4         Hounslow 2 - Cranford  2008              NaN     19.463412
# ..                          ...   ...              ...           ...
# 790              Oxford High St  2020              NaN           NaN
# 791  Oxford St Ebbes (Cal Club)  2020              NaN           NaN
# 792      Reading Caversham Road  2020              NaN           NaN
# 793         Reading Oxford Road  2020              NaN           NaN
# 794           Watford Town Hall  2020              NaN           NaN
#
#      Nitrogen dioxide  Oxides of Nitrogen      Ozone  PM10 Particulate matter  \
# 0           35.637110           65.183649  31.628426                22.091612
# 1           37.730687           66.993132  34.426010                22.159977
# 2           37.439653           62.493307  41.626836                22.695308
# 3           34.516199           69.260681  31.764437                21.877800
# 4           36.025263           65.728967  36.527434                19.221030
# ..                ...                 ...        ...                      ...
# 790         28.006868                 NaN        NaN                      NaN
# 791               NaN                 NaN  46.380779                      NaN
# 792         24.945059                 NaN        NaN                      NaN
# 793         19.730862                 NaN        NaN                      NaN
# 794         20.813022                 NaN        NaN                      NaN
#
#      PM10 particulate matter (Hourly measured)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 790                                  15.914070
# 791                                        NaN
# 792                                  20.666082
# 793                                  18.177858
# 794                                  13.758945
#
#      PM2.5 particulate matter (Hourly measured)  Sulphur dioxide  \
# 0                                           NaN         3.611565
# 1                                           NaN         3.959997
# 2                                           NaN         3.018580
# 3                                           NaN         2.886371
# 4                                           NaN         3.046298
# ..                                          ...              ...
# 790                                         NaN              NaN
# 791                                         NaN              NaN
# 792                                         NaN              NaN
# 793                                         NaN              NaN
# 794                                    7.877282              NaN
#
#      Nitric oxide       CCG                            lat/long  \
# 0             NaN  Hounslow            [51.4686132, -0.3613471]
# 1             NaN  Hounslow            [51.4686132, -0.3613471]
# 2             NaN  Hounslow            [51.4686132, -0.3613471]
# 3             NaN  Hounslow            [51.4686132, -0.3613471]
# 4             NaN  Hounslow            [51.4686132, -0.3613471]
# ..            ...       ...                                 ...
# 790           NaN    Oxford            [51.7520131, -1.2578499]
# 791           NaN    Oxford              [51.744856, -1.260338]
# 792           NaN   Reading            [51.4591971, -0.9723236]
# 793           NaN   Reading  [51.75397495, -1.2549151872177409]
# 794           NaN   Watford            [51.6589841, -0.4032651]
#
#      distance_from_LHR Radius
# 0             6.440137  Inner
# 1             6.440137  Inner
# 2             6.440137  Inner
# 3             6.440137  Inner
# 4             6.440137  Inner
# ..                 ...    ...
# 790          63.733402  Outer
# 791          63.500050  Outer
# 792          35.906170  Outer
# 793          63.663925  Outer
# 794          21.305890  Outer
#
# [795 rows x 16 columns]

# %%
poll1 = poll[~poll.Location.str.contains("Heathrow")]

# %%
all_polls = list(poll1.drop(['Location', 'Date', 'CCG', 'Radius', 'lat/long', 'distance_from_LHR'], axis = 1).columns)


for p in all_polls:
    plt.figure(figsize=(10, 6))
    sns.lineplot(y= p,
                 x='Date',
                 hue = 'Radius',
                 data=poll1).set_title(p)
    plt.xticks(rotation=90)
    plt.show()

# %%
all_polls = list(poll1.drop(['Location', 'Date', 'CCG', 'Radius', 'lat/long', 'distance_from_LHR'], axis = 1).columns)


for p in all_polls:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(y= p,
                 x='distance_from_LHR',
                 hue = 'CCG',
                 data=poll1).set_title(p)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ## Combining Datasets

# %%
health = pd.read_csv('../data_final/health_data_final_wide_format.csv').drop('Unnamed: 0', axis =1)

# %%
health
# Out:
#      Year                Area Name Radius Location  heathrow_distance  \
# 0    2003   NHS Berkshire West CCG           Outer        49791.74229
# 1    2003            NHS Brent CCG           Outer        16247.54245
# 2    2003  NHS Buckinghamshire CCG           Outer        38818.06153
# 3    2003          NHS Croydon CCG           Outer        28645.84070
# 4    2003           NHS Ealing CCG           Inner        11465.53093
# ..    ...                      ...             ...                ...
# 327  2019      NHS Oxfordshire CCG           Outer        66982.40789
# 328  2019         NHS Richmond CCG           Inner        11948.41495
# 329  2019     NHS Surrey Heath CCG           Outer        23497.23959
# 330  2019           NHS Sutton CCG           Outer        23268.28951
# 331  2019       NHS Wandsworth CCG           Outer        17762.40187
#
#               CCG_Poll_Map      LAT     LONG  \
# 0                  Reading  51.4458 -1.16963
# 1    No Pollution Readings  51.5644 -0.27568
# 2    No Pollution Readings  51.7414 -0.80644
# 3    No Pollution Readings  51.3660 -0.07761
# 4                   Ealing  51.5244 -0.31405
# ..                     ...      ...      ...
# 327                 Oxford  51.7715 -1.29146
# 328      South West London  51.4403 -0.28911
# 329  No Pollution Readings  51.3281 -0.70434
# 330      South West London  51.3576 -0.17227
# 331      South West London  51.4524 -0.20028
#
#      <75 Coronary Heart Disease Mortality Rate  Asthma Admissions Over 19yr  \
# 0                                        57.82                          NaN
# 1                                        76.04                          NaN
# 2                                        51.21                          NaN
# 3                                        65.63                          NaN
# 4                                        82.91                          NaN
# ..                                         ...                          ...
# 327                                        NaN                          NaN
# 328                                        NaN                          NaN
# 329                                        NaN                          NaN
# 330                                        NaN                          NaN
# 331                                        NaN                          NaN
#
#      Asthma Admissions Under 19yr  ...  Hypertension Prevalence  \
# 0                             NaN  ...                      NaN
# 1                             NaN  ...                      NaN
# 2                             NaN  ...                      NaN
# 3                             NaN  ...                      NaN
# 4                             NaN  ...                      NaN
# ..                            ...  ...                      ...
# 327                           NaN  ...                12.590274
# 328                           NaN  ...                 9.472279
# 329                           NaN  ...                14.408195
# 330                           NaN  ...                12.948442
# 331                           NaN  ...                 8.132270
#
#      Pneumonia (all mentions) Mortality Rate  Pneumonia Admissions  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        NaN                   NaN
# 3                                        NaN                   NaN
# 4                                        NaN                   NaN
# ..                                       ...                   ...
# 327                                      NaN                   NaN
# 328                                      NaN                   NaN
# 329                                      NaN                   NaN
# 330                                      NaN                   NaN
# 331                                      NaN                   NaN
#
#      Respiratory Admissions  Respiratory Tract Admissions 1yr  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
# ..                      ...                               ...
# 327                     NaN                               NaN
# 328                     NaN                               NaN
# 329                     NaN                               NaN
# 330                     NaN                               NaN
# 331                     NaN                               NaN
#
#      Respiratory Tract Admissions U1yr  Stroke Admissions  \
# 0                                  NaN                NaN
# 1                                  NaN                NaN
# 2                                  NaN                NaN
# 3                                  NaN                NaN
# 4                                  NaN                NaN
# ..                                 ...                ...
# 327                                NaN                NaN
# 328                                NaN                NaN
# 329                                NaN                NaN
# 330                                NaN                NaN
# 331                                NaN                NaN
#
#      Stroke Atrial Fib Admissions  Stroke: Prevalence  \
# 0                             NaN                 NaN
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# ..                            ...                 ...
# 327                           NaN            1.731539
# 328                           NaN            1.147338
# 329                           NaN            1.637341
# 330                           NaN            1.329523
# 331                           NaN            0.816457
#
#      Under 75 Resp Disease Mortality Rate
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 327                                   NaN
# 328                                   NaN
# 329                                   NaN
# 330                                   NaN
# 331                                   NaN
#
# [332 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
from scipy import stats

# x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
# y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# need to mkae sure the matrixes/elements are the same length
x= tmp_df[tmp_df['Indicator Name'] == 'COPD Admissions'].dropna()['heathrow_distance'].to_numpy()
y = tmp_df[tmp_df['Indicator Name'] == 'COPD Admissions'].dropna()['Value'].to_numpy()


slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept


def get_y(y):
  return (y/slope) - intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()


print('distance of {0} has the potential to give {1} heart failure'.format(1000, myfunc(1000)))

print(r)
